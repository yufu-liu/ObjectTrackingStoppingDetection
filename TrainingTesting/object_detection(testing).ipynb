# %%
if __name__ == '__main__':
    from ultralytics import YOLO
    mode = 'subset'
    if mode == 'all':
        # Load the fine-tuned YOLOv8 model
        model = YOLO('your-model-path')
        # Test dataset path (make sure your test images are in this folder)
        test_data = 'D:/Dataset/dana36/yolo_testing/data.yaml'
    elif mode == 'subset':
        # Load the fine-tuned YOLOv8 model
        model = YOLO('your-model-path')
        # Test dataset path (make sure your test images are in this folder)
        test_data = 'D:/Dataset/dana36/subset_yolo_testing/data.yaml'
    # Perform evaluation on the testing set
    results = model.val(data=test_data)

    # Display the evaluation results
    print("Results:", results)
# Out:
# Ultralytics YOLOv8.0.26  Python-3.8.10 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\Dataset\dana36\subset_yolo_testing\labels.cache... 2906 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2906/2906 [00:00<?, ?it/s]Scanning D:\Dataset\dana36\subset_yolo_testing\labels.cache... 2906 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2906/2906 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 182/182 [01:28<00:00,  2.06it/s]
#                    all       2906       3155      0.772      0.862      0.892      0.806
#                vehicle       2906        919      0.484      0.927      0.775      0.713
#                   male       2906       1495      0.896      0.849      0.951      0.866
#                 female       2906        741      0.935      0.808      0.951       0.84
# ...
