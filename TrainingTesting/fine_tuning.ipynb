# %%
if __name__ == '__main__':
    from ultralytics import YOLO

    # Load a pretrained YOLOv8 model
    model = YOLO('yolov8n.pt')  # Replace 'yolov8n.pt' with the desired model size (e.g., yolov8s.pt, yolov8m.pt)

    # Train the model
    mode = 'subset'
    if mode == 'all':
        model.train(data='D:/Dataset/dana36/yolo_data/data.yaml', epochs=50, imgsz=416, batch=32, device='0', patience=5)
    elif mode == 'subset':
        model.train(data='D:/Dataset/dana36/subset_yolo_data/data.yaml', epochs=50, imgsz=416, batch=64, device='0', patience=5)
